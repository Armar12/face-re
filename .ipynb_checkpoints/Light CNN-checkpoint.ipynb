# %%
import tensorflow as tf
import numpy as np
import os
from numpy import genfromtxt
from keras import backend as K
from keras.layers import Conv2D, ZeroPadding2D, Activation, Input, concatenate,Permute,Reshape,Cropping2D,Maximum,Cropping1D
from keras.models import Model
from keras.layers.normalization import BatchNormalization
from keras.layers.pooling import MaxPooling2D, AveragePooling2D
import fr_utils
from keras.layers.core import Lambda, Flatten, Dense
from theano.tensor import _shared
from keras.utils import to_categorical

# %%
import pickle
import os
f = open('train_set_new.pkl','rb+')
train_set =pickle.load(f)

# %%
image_tensor =  _shared(train_set[0]['Aaron_Peirsol'])
print(train_set[0]['Aaron_Peirsol'].shape)
y=np.ones((3,1))
print(y.shape)
input_image = Input(shape=(img_size, img_size, n_channel))

type(image_tensor)
# Out:
# (3, 250, 250, 3)
# (3, 1)
# theano.tensor.sharedvar.TensorSharedVariable

# %%
def conv2d_bn(x, filters, kernel_size, strides=1, padding='same', activation='relu', use_bias=False, name=None):
    x = Conv2D(filters, kernel_size, strides=strides, padding=padding, use_bias=use_bias, kernel_initializer='he_normal', name=name)(x)
    if not use_bias:
        bn_axis = 1 if K.image_data_format() == 'channels_first' else 3
        bn_name = None if name is None else name + '_bn'
        x = BatchNormalization(axis=bn_axis, scale=False, name=bn_name)(x)
    return x

def mfm(x):
    shape = K.int_shape(x)
    x = Permute(dims=(3, 2, 1))(x) # swap 1 <-> 3 axis
    x1 = Cropping2D(cropping=((0, shape[3] // 2), 0))(x)
    x2 = Cropping2D(cropping=((shape[3] // 2, 0), 0))(x)
    x = Maximum()([x1, x2])
    x = Permute(dims=(3, 2, 1))(x) # swap 1 <-> 3 axis
    x = Reshape([shape[1], shape[2], shape[3] // 2])(x)
    return x

def common_conv2d(net, filters, filters2):
    res = net

    net = conv2d_bn(net, filters=filters, kernel_size=1, strides=1, padding='same')
    net = mfm(net)
    net = conv2d_bn(net, filters=filters2, kernel_size=3, strides=1, padding='same')
    net = mfm(net)

    return net

def lcnn9(inputs):
    # Conv1
    net = conv2d_bn(inputs, filters=96, kernel_size=5, strides=1, padding='same')
    net = mfm(net)
    net = MaxPooling2D(pool_size=2, strides=2, padding='same')(net)

    # Block1
    net = common_conv2d(net,filters=96, filters2=192)
    net = MaxPooling2D(pool_size=2, strides=2, padding='same')(net)

    # Block2
    net = common_conv2d(net,filters=192, filters2=384)
    net = MaxPooling2D(pool_size=2, strides=2, padding='same')(net)

    # Block3
    net = common_conv2d(net,filters=384, filters2=256)

    # Block4
    net = common_conv2d(net,filters=256, filters2=256)
    net = MaxPooling2D(pool_size=2, strides=2, padding='same')(net)

    net = Flatten()(net)

    return net

# %%
input_image = Input(shape=(250, 250, 3))

lcnn_output = lcnn9(inputs=input_image)

fc1 = Dense(512, activation=None)(lcnn_output)
fc1 = Reshape((512, 1))(fc1)
fc1_1 = Cropping1D(cropping=(0, 256))(fc1)
fc1_2 = Cropping1D(cropping=(256, 0))(fc1)
fc1 = Maximum()([fc1_1, fc1_2])
fc1 = Flatten()(fc1)

out = Dense(18, activation='softmax')(fc1)
model = Model(inputs=[input_image], outputs=out)

# %%
y=np.ones((3,1),dtype='int')
model.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])
model.fit(x_train[:32],to_categorical(y_train[:32],18),epoch=5,batch_size=8)
# Out:
# C:\Users\ningj\AppData\Roaming\Python\Python36\site-packages\ipykernel_launcher.py:3: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
#   This is separate from the ipykernel package so we can avoid doing imports until
# Epoch 1/5
# 32/32 [==============================] - 155s 5s/step - loss: 12.0997 - acc: 0.0625
# Epoch 2/5
# 32/32 [==============================] - 145s 5s/step - loss: 13.5996 - acc: 0.1562
# Epoch 3/5
# 32/32 [==============================] - 148s 5s/step - loss: 13.5996 - acc: 0.1562
# Epoch 4/5
# 32/32 [==============================] - 144s 5s/step - loss: 13.5996 - acc: 0.1562
# Epoch 5/5
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-42-d3910e45cedc> in <module>()
#       1 y=np.ones((3,1),dtype='int')
#       2 model.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])
# ----> 3 model.fit(x_train[:32],to_categorical(y_train[:32],18),nb_epoch=5,batch_size=8)
#
# ~\AppData\Local\conda\conda\envs\bitch\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1667                               initial_epoch=initial_epoch,
#    1668                               steps_per_epoch=steps_per_epoch,
# -> 1669                               validation_steps=validation_steps)
#    1670
#    1671     def evaluate(self, x=None, y=None,
#
# ~\AppData\Local\conda\conda\envs\bitch\lib\site-packages\keras\engine\training.py in _fit_loop(self, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#    1204                         ins_batch[i] = ins_batch[i].toarray()
#    1205
# -> 1206                     outs = f(ins_batch)
#    1207                     if not isinstance(outs, list):
#    1208                         outs = [outs]
#
# ~\AppData\Local\conda\conda\envs\bitch\lib\site-packages\keras\backend\tensorflow_backend.py in __call__(self, inputs)
#    2473         session = get_session()
#    2474         updated = session.run(fetches=fetches, feed_dict=feed_dict,
# -> 2475                               **self.session_kwargs)
#    2476         return updated[:len(self.outputs)]
#    2477
#
# ~\AppData\Local\conda\conda\envs\bitch\lib\site-packages\tensorflow\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     776     try:
#     777       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 778                          run_metadata_ptr)
#     779       if run_metadata:
#     780         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~\AppData\Local\conda\conda\envs\bitch\lib\site-packages\tensorflow\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     980     if final_fetches or final_targets:
#     981       results = self._do_run(handle, final_targets, final_fetches,
# --> 982                              feed_dict_string, options, run_metadata)
#     983     else:
#     984       results = []
#
# ~\AppData\Local\conda\conda\envs\bitch\lib\site-packages\tensorflow\python\client\session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1030     if handle is None:
#    1031       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1032                            target_list, options, run_metadata)
#    1033     else:
#    1034       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# ~\AppData\Local\conda\conda\envs\bitch\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1037   def _do_call(self, fn, *args):
#    1038     try:
# -> 1039       return fn(*args)
#    1040     except errors.OpError as e:
#    1041       message = compat.as_text(e.message)
#
# ~\AppData\Local\conda\conda\envs\bitch\lib\site-packages\tensorflow\python\client\session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1019         return tf_session.TF_Run(session, options,
#    1020                                  feed_dict, fetch_list, target_list,
# -> 1021                                  status, run_metadata)
#    1022
#    1023     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
x_train=[]
y_train=[]
label=[]
num=0
k=list(range(5749))
for key,val in train_set[0].items():
    label.append(key)
    y_train.append(np.asarray([num]*val.shape[0]))
    num+=1
    x_train.append(val)

# %%
x_train=np.asarray(x_train)
y_train=np.asarray(y_train).reshape(5749,1)

labels=dict(zip(k,label))

# %%
print(y_train[:32].shape)
# Out:
# (32, 1)

# %%
m=open('train_set.pkl','rb+')
dd=pickle.load(m)

# %%
re_label=dict(zip(label,k))
re_label
# Out:
# {'Aaron_Eckhart': 0,
#  'Aaron_Guiel': 1,
#  'Aaron_Patterson': 2,
#  'Aaron_Peirsol': 3,
#  'Aaron_Pena': 4,
#  'Aaron_Sorkin': 5,
#  'Aaron_Tippin': 6,
#  'Abbas_Kiarostami': 7,
#  'Abba_Eban': 8,
#  'Abdel_Aziz_Al-Hakim': 9,
#  'Abdel_Madi_Shabneh': 10,
#  'Abdel_Nasser_Assidi': 11,
#  'Abdoulaye_Wade': 12,
#  'Abdulaziz_Kamilov': 13,
#  'Abdullah': 14,
#  'Abdullah_Ahmad_Badawi': 15,
#  'Abdullah_al-Attiyah': 16,
#  'Abdullah_Gul': 17,
#  'Abdullah_Nasseef': 18,
#  'Abdullatif_Sener': 19,
#  'Abdul_Majeed_Shobokshi': 20,
#  'Abdul_Rahman': 21,
#  'Abel_Aguilar': 22,
#  'Abel_Pacheco': 23,
#  'Abid_Hamid_Mahmud_Al-Tikriti': 24,
#  'Abner_Martinez': 25,
#  'Abraham_Foxman': 26,
#  'Aby_Har-Even': 27,
#  'Adam_Ant': 28,
#  'Adam_Freier': 29,
#  'Adam_Herbert': 30,
#  'Adam_Kennedy': 31,
#  'Adam_Mair': 32,
#  'Adam_Rich': 33,
#  'Adam_Sandler': 34,
#  'Adam_Scott': 35,
#  'Adelina_Avila': 36,
#  'Adel_Al-Jubeir': 37,
#  'Adisai_Bodharamik': 38,
#  'Adolfo_Aguilar_Zinser': 39,
#  'Adolfo_Rodriguez_Saa': 40,
#  'Adoor_Gopalakarishnan': 41,
#  'Adriana_Lima': 42,
#  'Adriana_Perez_Navarro': 43,
#  'Adrianna_Zuzic': 44,
#  'Adrian_Annus': 45,
#  'Adrian_Fernandez': 46,
#  'Adrian_McPherson': 47,
#  'Adrian_Murrell': 48,
#  'Adrian_Nastase': 49,
#  'Adrien_Brody': 50,
#  'Afton_Smith': 51,
#  'Agbani_Darego': 52,
#  'Agnelo_Queiroz': 53,
#  'Agnes_Bruckner': 54,
#  'Ahmad_Jbarah': 55,
#  'Ahmad_Masood': 56,
#  'Ahmed_Ahmed': 57,
#  'Ahmed_Chalabi': 58,
#  'Ahmed_Ghazi': 59,
#  'Ahmed_Ibrahim_Bilal': 60,
#  'Ahmed_Lopez': 61,
#  'Ahmed_Qureia': 62,
#  'Ahmet_Demir': 63,
#  'Ahmet_Necdet_Sezer': 64,
#  'Aicha_El_Ouafi': 65,
#  'Aidan_Quinn': 66,
#  'Aileen_Riggin_Soule': 67,
#  'Ainsworth_Dyer': 68,
#  'Ain_Seppik': 69,
#  'Aishwarya_Rai': 70,
#  'Aitor_Gonzalez': 71,
#  'Aiysha_Smith': 72,
#  'Ai_Sugiyama': 73,
#  'Ajit_Agarkar': 74,
#  'AJ_Cook': 75,
#  'AJ_Lamas': 76,
#  'Akbar_Al_Baker': 77,
#  'Akbar_Hashemi_Rafsanjani': 78,
#  'Akhmed_Zakayev': 79,
#  'Akiko_Morigami': 80,
#  'Akmal_Taher': 81,
#  'Alain_Cervantes': 82,
#  'Alain_Ducasse': 83,
#  'Alanis_Morissette': 84,
#  'Alanna_Ubach': 85,
#  'Alan_Ball': 86,
#  'Alan_Dershowitz': 87,
#  'Alan_Dreher': 88,
#  'Alan_Greenspan': 89,
#  'Alan_Greer': 90,
#  'Alan_Jackson': 91,
#  'Alan_Mulally': 92,
#  'Alan_Stonecipher': 93,
#  'Alan_Tang_Kwong-wing': 94,
#  'Alan_Trammell': 95,
#  'Alan_Zemaitis': 96,
#  'Alastair_Campbell': 97,
#  'Alastair_Johnston': 98,
#  'Albaro_Recoba': 99,
#  'Alberta_Lee': 100,
#  'Alberto_Acosta': 101,
#  'Alberto_Fujimori': 102,
#  'Alberto_Gonzales': 103,
#  'Alberto_Ruiz_Gallardon': 104,
#  'Alberto_Sordi': 105,
#  'Albert_Brooks': 106,
#  'Albert_Costa': 107,
#  'Albert_Montanes': 108,
#  'Albert_Pujols': 109,
#  'Albrecht_Mentz': 110,
#  'Aldo_Paredes': 111,
#  'Alecos_Markides': 112,
#  'Alec_Baldwin': 113,
#  'Alejandro_Atchugarry': 114,
#  'Alejandro_Avila': 115,
#  'Alejandro_Fernandez': 116,
#  'Alejandro_Gonzalez_Inarritu': 117,
#  'Alejandro_Lembo': 118,
#  'Alejandro_Lerner': 119,
#  'Alejandro_Lopez': 120,
#  'Alejandro_Toledo': 121,
#  'Aleksander_Kwasniewski': 122,
#  'Aleksander_Voloshin': 123,
#  'Alek_Wek': 124,
#  'Alessandra_Cerna': 125,
#  'Alessandro_Nesta': 126,
#  'Alexander_Downer': 127,
#  'Alexander_Losyukov': 128,
#  'Alexander_Lukashenko': 129,
#  'Alexander_Payne': 130,
#  'Alexander_Rumyantsev': 131,
#  'Alexandra_Jackson': 132,
#  'Alexandra_Pelosi': 133,
#  'Alexandra_Rozovskaya': 134,
#  'Alexandra_Spann': 135,
#  'Alexandra_Stevenson': 136,
#  'Alexandra_Vodjanikova': 137,
#  'Alexandre_Daigle': 138,
#  'Alexandre_Despatie': 139,
#  'Alexandre_Herchcovitch': 140,
#  'Alexandre_Vinokourov': 141,
#  'Alexa_Loren': 142,
#  'Alexa_Vega': 143,
#  'Alexis_Bledel': 144,
#  'Alexis_Dennisoff': 145,
#  'Alex_Barros': 146,
#  'Alex_Cabrera': 147,
#  'Alex_Cejka': 148,
#  'Alex_Corretja': 149,
#  'Alex_Ferguson': 150,
#  'Alex_Gonzalez': 151,
#  'Alex_Holmes': 152,
#  'Alex_King': 153,
#  'Alex_Penelas': 154,
#  'Alex_Popov': 155,
#  'Alex_Sink': 156,
#  'Alex_Wallau': 157,
#  'Alex_Zanardi': 158,
#  'Alfonso_Cuaron': 159,
#  'Alfonso_Portillo': 160,
#  'Alfonso_Soriano': 161,
#  'Alfredo_di_Stefano': 162,
#  'Alfredo_Moreno': 163,
#  'Alfredo_Pena': 164,
#  'Alfred_Ford': 165,
#  'Alfred_Sant': 166,
#  'Alice_Fisher': 167,
#  'Alicia_Hollowell': 168,
#  'Alicia_Keys': 169,
#  'Alicia_Molik': 170,
#  'Alicia_Silverstone': 171,
#  'Alicia_Witt': 172,
#  'Alimzhan_Tokhtakhounov': 173,
#  'Alina_Kabaeva': 174,
#  'Aline_Chretien': 175,
#  'Alisha_Richman': 176,
#  'Alison_Krauss': 177,
#  'Alison_Lohman': 178,
#  'Alistair_MacDonald': 179,
#  'Ali_Abbas': 180,
#  'Ali_Abdullah_Saleh': 181,
#  'Ali_Adbul_Karim_Madani': 182,
#  'Ali_Ahmeti': 183,
#  'Ali_Bin_Hussein': 184,
#  'Ali_Fallahian': 185,
#  'Ali_Hammoud': 186,
#  'Ali_Khamenei': 187,
#  'Ali_Mohammed_Maher': 188,
#  'Ali_Naimi': 189,
#  'Allan_Houston': 190,
#  'Allan_Kemakeza': 191,
#  'Allan_Wagner': 192,
#  'Allen_Iverson': 193,
#  'Allen_Rock': 194,
#  'Allison_Janney': 195,
#  'Allison_Searing': 196,
#  'Allyson_Felix': 197,
#  'Ally_Sheedy': 198,
#  'Alma_Powell': 199,
#  'Almeida_Baptista': 200,
#  'Alonzo_Mourning': 201,
#  'Alvaro_Noboa': 202,
#  'Alvaro_Silva_Calderon': 203,
#  'Alvaro_Uribe': 204,
#  'Alyse_Beaupre': 205,
#  'Alyson_Hannigan': 206,
#  'Aly_Wagner': 207,
#  'Al_Cardenas': 208,
#  'Al_Davis': 209,
#  'Al_Gore': 210,
#  'Al_Leiter': 211,
#  'Al_Pacino': 212,
#  'Al_Sharpton': 213,
#  'Amanda_Beard': 214,
#  'Amanda_Bynes': 215,
#  'Amanda_Coetzer': 216,
#  'Amanda_Marsh': 217,
#  'Amanda_Plumer': 218,
#  'Amber_Frey': 219,
#  'Amber_Tamblyn': 220,
#  'Ambrose_Lee': 221,
#  'Amelia_Vega': 222,
#  'Amelie_Mauresmo': 223,
#  'Amer_al-Saadi': 224,
#  'Amporn_Falise': 225,
#  'Amram_Mitzna': 226,
#  'Amr_Moussa': 227,
#  'Amy_Brenneman': 228,
#  'Amy_Cotton': 229,
#  'Amy_Gale': 230,
#  'Amy_Pascal': 231,
#  'Amy_Redford': 232,
#  'Amy_Smart': 233,
#  'Amy_Yasbeck': 234,
#  'Anastasia_Kelesidou': 235,
#  'Anastasia_Myskina': 236,
#  'Anatoliy_Kinakh': 237,
#  'Ana_Claudia_Talancon': 238,
#  'Ana_Guevara': 239,
#  'Ana_Isabel_Sanchez': 240,
#  'Ana_Palacio': 241,
#  'Ana_Paula_Gerard': 242,
#  'Ana_Sebastiao': 243,
#  'Anderson_Varejao': 244,
#  'Anders_Ebbeson': 245,
#  'Anders_Fogh_Rasmussen': 246,
#  'Andreas_Vinciguerra': 247,
#  'Andrea_Bocelli': 248,
#  'Andrea_De_Cruz': 249,
#  'Andrea_Kiser': 250,
#  'Andrea_Yates': 251,
#  'Andrei_Konchalovsky': 252,
#  'Andrei_Mikhnevich': 253,
#  'Andrei_Nikolishin': 254,
#  'Andres_DAlessandro': 255,
#  'Andres_Manuel_Lopez_Obrador': 256,
#  'Andres_Pastrana': 257,
#  'Andrew_Bernard': 258,
#  'Andrew_Bunner': 259,
#  'Andrew_Caldecott': 260,
#  'Andrew_Cuomo': 261,
#  'Andrew_Fastow': 262,
#  'Andrew_Firestone': 263,
#  'Andrew_Gilligan': 264,
#  'Andrew_Jarecki': 265,
#  'Andrew_Luster': 266,
#  'Andrew_Niccol': 267,
#  'Andrew_Sabey': 268,
#  'Andrew_Shutley': 269,
#  'Andrew_Weissmann': 270,
#  'Andrew_Wetzler': 271,
#  'Andre_Agassi': 272,
#  'Andre_Bucher': 273,
#  'Andre_Lange': 274,
#  'Andre_Smith': 275,
#  'Andre_Techine': 276,
#  'Andrzej_Tyszkiewicz': 277,
#  'Andy_Benes': 278,
#  'Andy_Bryant': 279,
#  'Andy_Dick': 280,
#  'Andy_Garcia': 281,
#  'Andy_Graves': 282,
#  'Andy_Griffith': 283,
#  'Andy_Griggs': 284,
#  'Andy_Hebb': 285,
#  'Andy_Lau': 286,
#  'Andy_Madikians': 287,
#  'Andy_North': 288,
#  'Andy_Perez': 289,
#  'Andy_Roddick': 290,
#  'Andy_Rooney': 291,
#  'Andy_Warhol': 292,
#  'Andy_Wisecarver': 293,
#  'Anette_Hosoi': 294,
#  'AnFernce_Negron': 295,
#  'Angela_Alvarado_Rosa': 296,
#  'Angela_Bassett': 297,
#  'Angela_Lansbury': 298,
#  'Angela_Mascia-Frye': 299,
#  'Angela_Merkel': 300,
#  'Angelica_Romero': 301,
#  'Angelina_Jolie': 302,
#  'Angelo_Genova': 303,
#  'Angelo_Reyes': 304,
#  'Angel_Lockward': 305,
#  'Angel_Maza': 306,
#  'Angie_Arzola': 307,
#  'Angie_Martinez': 308,
#  'Anibal_Ibarra': 309,
#  'Anil_Ramsook': 310,
#  'Anita_DeFrantz': 311,
#  'Anja_Paerson': 312,
#  'Anjum_Hussain': 313,
#  'Anna_Chicherova': 314,
#  'Anna_Faris': 315,
#  'Anna_Jones': 316,
#  'Anna_Kournikova': 317,
#  'Anna_Nicole_Smith': 318,
#  'Anneli_Jaatteenmaki': 319,
#  'Annette_Bening': 320,
#  'Annette_Lu': 321,
#  'Anne_Cavers': 322,
#  'Anne_Donovan': 323,
#  'Anne_Heche': 324,
#  'Anne_Krueger': 325,
#  'Anne_McLellan': 326,
#  'Anne_ONeil': 327,
#  'Annie-Jeanne_Reynaud': 328,
#  'Annie_Chaplin': 329,
#  'Annie_Machon': 330,
#  'Annika_Sorenstam': 331,
#  'Ann_Godbehere': 332,
#  'Ann_Landers': 333,
#  'Ann_Morgan': 334,
#  'Ann_Veneman': 335,
#  'Antanas_Valionis': 336,
#  'Anthony_Carter': 337,
#  'Anthony_Corso': 338,
#  'Anthony_Ervin': 339,
#  'Anthony_Fauci': 340,
#  'Anthony_Garotinho': 341,
#  'Anthony_Hazen': 342,
#  'Anthony_Hopkins': 343,
#  'Anthony_LaPaglia': 344,
#  'Anthony_Lee_Johnson': 345,
#  'Anthony_Mazur': 346,
#  'Anthony_Pico': 347,
#  'Anthony_Pisciotti': 348,
#  'Anthony_Principi': 349,
#  'Anthony_Rackauckas': 350,
#  'Anthony_Scott_Miller': 351,
#  'Antje_Buschschulte': 352,
#  'Antonio_Banderas': 353,
#  'Antonio_Bernardo': 354,
#  'Antonio_Cassano': 355,
#  'Antonio_Catania': 356,
#  'Antonio_Elias_Saca': 357,
#  'Antonio_Palocci': 358,
#  'Antonio_Trillanes': 359,
#  'Antony_Leung': 360,
#  'Anton_Balasingham': 361,
#  'Antwun_Echols': 362,
#  'Anwar_Ibrahim': 363,
#  'Anzori_Kikalishvili': 364,
#  'Aparna_Pillai': 365,
#  'Aram_Adler': 366,
#  'Arantxa_Sanchez-Vicario': 367,
#  'Aretha_Franklin': 368,
#  'Arianna_Huffington': 369,
#  'Ariel_Sharon': 370,
#  'Arie_Haan': 371,
#  'Arif_Mardin': 372,
#  'Ari_Bousbib': 373,
#  'Ari_Fleischer': 374,
#  'Arlen_Specter': 375,
#  'Armando_Avila_Panchame': 376,
#  'Armando_Calderon_Sol': 377,
#  'Armando_Carrillo': 378,
#  'Armand_Sargen': 379,
#  'Arminio_Fraga': 380,
#  'Arnaud_Clement': 381,
#  'Arnaud_Lagardere': 382,
#  'Arnie_Boehm': 383,
#  'Arnoldo_Aleman': 384,
#  'Arnold_Palmer': 385,
#  'Arnold_Schwarzenegger': 386,
#  'Arnold_Scott': 387,
#  'Aron_Ralston': 388,
#  'Arsinee_Khanjian': 389,
#  'Arthur_Johnson': 390,
#  'Arthur_Martinez': 391,
#  'Artieas_Shanks': 392,
#  'Arturo_Gatti': 393,
#  'Art_Cooper': 394,
#  'Art_Hoffmann': 395,
#  'Art_Howe': 396,
#  'Art_Lopez': 397,
#  'Arye_Mekel': 398,
#  'Asa_Hutchinson': 399,
#  'Ascencion_Barajas': 400,
#  'Ashanti': 401,
#  'Ashlea_Talbot': 402,
#  'Ashley_Judd': 403,
#  'Ashley_Olsen': 404,
#  'Ashley_Postell': 405,
#  'Ashraf_Alasmar': 406,
#  'Ashraf_Ghani': 407,
#  'Ashton_Kutcher': 408,
#  'Asif_Ali_Zardari': 409,
#  'Asif_Hanif': 410,
#  'Askar_Akayev': 411,
#  'Asmaa_Assad': 412,
#  'Assad_Ahmadi': 413,
#  'Astou_Ndiaye-Diatta': 414,
#  'Astrid_Betancourt': 415,
#  'Astrid_Eyzaguirre': 416,
#  'Atal_Bihari_Vajpayee': 417,
#  'Ataollah_Mohajerani': 418,
#  'Atiabet_Ijan_Amabel': 419,
#  'Atom_Egoyan': 420,
#  'Atsushi_Sato': 421,
#  'Audrey_Lacroix': 422,
#  'Audrey_Sauret': 423,
#  'Augustin_Calleri': 424,
#  'Augusto_Pinochet': 425,
#  'Augusto_Roa_Bastos': 426,
#  'Aung_San_Suu_Kyi': 427,
#  'Austin_Kearns': 428,
#  'Avril_Lavigne': 429,
#  'Azmi_Bishara': 430,
#  'Azra_Akin': 431,
#  'Babe_Ruth': 432,
#  'Baburam_Bhattari': 433,
#  'Bak_Chang-Ryun': 434,
#  'Barbara_Bach': 435,
#  'Barbara_Becker': 436,
#  'Barbara_Bodine': 437,
#  'Barbara_Boxer': 438,
#  'Barbara_Brezigar': 439,
#  'Barbara_De_Brun': 440,
#  'Barbara_Esbin': 441,
#  'Barbara_Felt-Miller': 442,
#  'Barbara_Roberts': 443,
#  'Barbara_Walters': 444,
#  'Barbora_Strycova': 445,
#  'Barbra_Streisand': 446,
#  'Barrett_Jackman': 447,
#  'Barry_Alvarez': 448,
#  'Barry_Bonds': 449,
#  'Barry_Collier': 450,
#  'Barry_Diller': 451,
#  'Barry_Ford': 452,
#  'Barry_Hinson': 453,
#  'Barry_Nakell': 454,
#  'Barry_Switzer': 455,
#  'Barry_Williams': 456,
#  'Barry_Zito': 457,
#  'Bartosz_Kizierowski': 458,
#  'Bart_Freundlich': 459,
#  'Bart_Hendricks': 460,
#  'Barzan_al-Tikriti': 461,
#  'Basdeo_Panday': 462,
#  'Bashar_Assad': 463,
#  'Baz_Luhrmann': 464,
#  'BB_King': 465,
#  'Beatrice_Dalle': 466,
#  'Beatriz_Merino': 467,
#  'Beecher_Ray_Kirby': 468,
#  'Begum_Khaleda_Zia': 469,
#  'Bela_Karolyi': 470,
#  'Benazir_Bhutto': 471,
#  'Benedita_da_Silva': 472,
#  'Benicio_Del_Toro': 473,
#  'Benito_Santiago': 474,
#  'Benjamin_Bratt': 475,
#  'Benjamin_Franklin': 476,
#  'Benjamin_Martinez': 477,
#  'Benjamin_McKenzie': 478,
#  'Benjamin_Netanyahu': 479,
#  'Benjamin_Neulander': 480,
#  'Ben_Affleck': 481,
#  'Ben_Betts': 482,
#  'Ben_Braun': 483,
#  'Ben_Broussard': 484,
#  'Ben_Cahoon': 485,
#  'Ben_Chandler': 486,
#  'Ben_Cohen': 487,
#  'Ben_Curtis': 488,
#  'Ben_Davis': 489,
#  'Ben_Glisan': 490,
#  'Ben_Howland': 491,
#  'Ben_Kingsley': 492,
#  'Ben_Lee': 493,
#  'Ben_Stein': 494,
#  'Ben_Wallace': 495,
#  'Bernadette_Peters': 496,
#  'Bernardo_Segura': 497,
#  'Bernard_Ebbers': 498,
#  'Bernard_Giraudeau': 499,
#  'Bernard_Kerik': 500,
#  'Bernard_Landry': 501,
#  'Bernard_Law': 502,
#  'Bernard_Lord': 503,
#  'Bernard_Siegel': 504,
#  'Bernice_Wong': 505,
#  'Bertie_Ahern': 506,
#  'Bertrand_Bonello': 507,
#  'Bertrand_Delanoe': 508,
#  'Beth_Blough': 509,
#  'Beth_Jones': 510,
#  'Betsy_Coffin': 511,
#  'Betsy_Smith': 512,
#  'Bettina_Rheims': 513,
#  'Betty_Garrison': 514,
#  'Betty_Williams': 515,
#  'Beyonce_Knowles': 516,
#  'Bianca_Jagger': 517,
#  'Bijan_Darvish': 518,
#  'Bijan_Namdar_Zangeneh': 519,
#  'Bilal_Erdogan': 520,
#  'Biljana_Plavsic': 521,
#  'Billy_Andrade': 522,
#  'Billy_Beane': 523,
#  'Billy_Bob_Thornton': 524,
#  'Billy_Boyd': 525,
#  'Billy_Crawford': 526,
#  'Billy_Crystal': 527,
#  'Billy_Donovan': 528,
#  'Billy_Edelin': 529,
#  'Billy_Gilman': 530,
#  'Billy_Graham': 531,
#  'Billy_Joel': 532,
#  'Billy_Rork': 533,
#  'Billy_Sollie': 534,
#  'Billy_Tibbets': 535,
#  'Bill_Belichick': 536,
#  'Bill_Bradley': 537,
#  'Bill_Butler': 538,
#  'Bill_Byrne': 539,
#  'Bill_Callahan': 540,
#  'Bill_Carmody': 541,
#  'Bill_Cartwright': 542,
#  'Bill_Clancy': 543,
#  'Bill_Clinton': 544,
#  'Bill_Curry': 545,
#  'Bill_Doba': 546,
#  'Bill_Duffey': 547,
#  'Bill_Elliott': 548,
#  'Bill_Fennelly': 549,
#  'Bill_Frist': 550,
#  'Bill_Gates': 551,
#  'Bill_Graham': 552,
#  'Bill_Guerin': 553,
#  'Bill_Herrion': 554,
#  'Bill_Hughes': 555,
#  'Bill_King': 556,
#  'Bill_Kollar': 557,
#  'Bill_Kong': 558,
#  'Bill_Lerach': 559,
#  'Bill_Maher': 560,
#  'Bill_Mauldin': 561,
#  'Bill_McBride': 562,
#  'Bill_Nelson': 563,
#  'Bill_OReilly': 564,
#  'Bill_Parcells': 565,
#  'Bill_Parsons': 566,
#  'Bill_Paxton': 567,
#  'Bill_Pryor': 568,
#  'Bill_Rainer': 569,
#  'Bill_Readdy': 570,
#  'Bill_Richardson': 571,
#  'Bill_Self': 572,
#  'Bill_Simon': 573,
#  'Bill_Sizemore': 574,
#  'Bill_Stapleton': 575,
#  'Bill_Stein': 576,
#  'Bill_Walton': 577,
#  'Bing_Crosby': 578,
#  'Binyamin_Ben-Eliezer': 579,
#  'Bison_Dele': 580,
#  'Bixente_LIzarazu': 581,
#  'BJ_Habibie': 582,
#  'Blas_Ople': 583,
#  'Blythe_Danner': 584,
#  'Blythe_Hartley': 585,
#  'Bobby_Bowden': 586,
#  'Bobby_Goldwater': 587,
#  'Bobby_Jackson': 588,
#  'Bobby_Kielty': 589,
#  'Bobby_Robson': 590,
#  'Bobo_Balde': 591,
#  'Bob_Alper': 592,
#  'Bob_Beauprez': 593,
#  'Bob_Bowlsby': 594,
#  'Bob_Cantrell': 595,
#  'Bob_Colvin': 596,
#  'Bob_Crippen': 597,
#  'Bob_Curtis': 598,
#  'Bob_Dole': 599,
#  'Bob_Eskridge': 600,
#  'Bob_Ferguson': 601,
#  'Bob_Geldof': 602,
#  'Bob_Goldman': 603,
#  'Bob_Graham': 604,
#  'Bob_Guccione': 605,
#  'Bob_Hartley': 606,
#  'Bob_Hayes': 607,
#  'Bob_Herz': 608,
#  'Bob_Holden': 609,
#  'Bob_Hope': 610,
#  'Bob_Huggins': 611,
#  'Bob_Iger': 612,
#  'Bob_Krueger': 613,
#  'Bob_Melvin': 614,
#  'Bob_Menendez': 615,
#  'Bob_Newhart': 616,
#  'Bob_Petrino': 617,
#  'Bob_Riley': 618,
#  'Bob_Stoops': 619,
#  'Bob_Sulkin': 620,
#  'Bob_Taft': 621,
#  'Bob_Wright': 622,
#  'Bode_Miller': 623,
#  'Bonnie_Fuller': 624,
#  'Bonnie_Hunt': 625,
#  'Bono': 626,
#  'Boris_Becker': 627,
#  'Boris_Berezovsky': 628,
#  'Boris_Henry': 629,
#  'Boris_Jordan': 630,
#  'Boris_Trajkovski': 631,
#  'Boris_Yeltsin': 632,
#  'Boutros_Boutros_Ghali': 633,
#  'Bo_Pelini': 634,
#  'Bo_Ryan': 635,
#  'Brady_Rodgers': 636,
#  'Brad_Alexander_Smith': 637,
#  'Brad_Banks': 638,
#  'Brad_Brownell': 639,
#  'Brad_Garrett': 640,
#  'Brad_Gushue': 641,
#  'Brad_Johnson': 642,
#  'Brad_Miller': 643,
#  'Brad_Pitt': 644,
#  'Brad_Russ': 645,
#  'Brad_Smith': 646,
#  'Brad_Wilk': 647,
#  'Brajesh_Mishra': 648,
#  'Brandon_Boyd': 649,
#  'Brandon_Fails': 650,
#  'Brandon_Hammond': 651,
#  'Brandon_Inge': 652,
#  'Brandon_Jones': 653,
#  'Brandon_Knight': 654,
#  'Brandon_Larson': 655,
#  'Brandon_Lloyd': 656,
#  'Brandon_Robinson': 657,
#  'Brandon_Spann': 658,
#  'Brandon_Webb': 659,
#  'Branko_Crvenkovski': 660,
#  'Brawley_King': 661,
#  'Brendan_Fraser': 662,
#  'Brendan_Gaughan': 663,
#  'Brendan_Hansen': 664,
#  'Brendan_Stai': 665,
#  'Brenda_Magana': 666,
#  'Brenda_van_Dam': 667,
#  'Brenda_Wilson': 668,
#  'Brennon_Leighton': 669,
#  'Brent_Coles': 670,
#  'Brett_Boone': 671,
#  'Brett_Hawke': 672,
#  'Brett_Hull': 673,
#  'Brett_Perry': 674,
#  'Brian_Billick': 675,
#  'Brian_Campbell': 676,
#  'Brian_Cashman': 677,
#  'Brian_Clemens': 678,
#  'Brian_Cook': 679,
#  'Brian_Cowen': 680,
#  'Brian_De_Palma': 681,
#  'Brian_Florence': 682,
#  'Brian_Grazier': 683,
#  'Brian_Gregory': 684,
#  'Brian_Griese': 685,
#  'Brian_Heidik': 686,
#  'Brian_Henson': 687,
#  'Brian_Jordan': 688,
#  'Brian_Kerr': 689,
#  'Brian_Lara': 690,
#  'Brian_McIntyre': 691,
#  'Brian_Meadors': 692,
#  'Brian_Mulroney': 693,
#  'Brian_Olson': 694,
#  'Brian_Pavlich': 695,
#  'Brian_Scalabrine': 696,
#  'Brian_Schneider': 697,
#  'Brian_StPierre': 698,
#  'Brian_Van_Dusen': 699,
#  'Brian_Weaver': 700,
#  'Brian_Wells': 701,
#  'Brian_Williams': 702,
#  'Bridgette_Wilson-Sampras': 703,
#  'Bridget_Fonda': 704,
#  'Brigitte_Boisselier': 705,
#  'Britney_Spears': 706,
#  'Brittany_Snow': 707,
#  'Brock_Berlin': 708,
#  'Bronson_Arroyo': 709,
#  'Brooke_Adams': 710,
#  'Brooke_Gordon': 711,
#  'Brooke_Shields': 712,
#  'Brook_Robinson': 713,
#  'Bruce_Arena': 714,
#  'Bruce_Gebhardt': 715,
#  'Bruce_Lunsford': 716,
#  'Bruce_Paltrow': 717,
#  'Bruce_Springsteen': 718,
#  'Bruce_Van_De_Velde': 719,
#  'Bruce_Weber': 720,
#  'Bruce_Willis': 721,
#  'Bruna_Colosio': 722,
#  'Bruno_Junquiera': 723,
#  'Bryant_Young': 724,
#  'Bryan_Adams': 725,
#  'Bryan_Chui': 726,
#  'Bryan_Cooley': 727,
#  'Bryan_Murray': 728,
#  'Bryan_Thomas': 729,
#  'Bryce_Carmine': 730,
#  'Buck_Rodgers': 731,
#  'Buddy_Ryan': 732,
#  'Budd_Schulberg': 733,
#  'Bud_Selig': 734,
#  'Buford_Blount': 735,
#  'Bulent_Ecevit': 736,
#  'Bustam_A_Zedan_Aljanabi': 737,
#  'Butch_Davis': 738,
#  'Buzz_Hargrove': 739,
#  'Byron_Scott': 740,
#  'Cabas': 741,
#  'Caio_Blat': 742,
#  'Calbert_Cheaney': 743,
#  'Calista_Flockhart': 744,
#  'Calvin_Harrison': 745,
#  'Calvin_Joseph_Coleman': 746,
#  'Cameron_Diaz': 747,
#  'Camilla_Parker_Bowles': 748,
#  'Camille_Colvin': 749,
#  'Camille_Lewis': 750,
#  'Camryn_Manheim': 751,
#  'Candace_Sutton': 752,
#  'Candice_Beatty': 753,
#  'Candice_Bergen': 754,
#  'Candie_Kung': 755,
#  'Carey_Lowell': 756,
#  'Carina_Lau_Ka-ling': 757,
#  'Carin_Koch': 758,
#  'Cari_Davis': 759,
#  'Carla_Del_Ponte': 760,
#  'Carla_Gay_Balingit': 761,
#  'Carla_Gugino': 762,
#  'Carla_Moreno': 763,
#  'Carla_Myers': 764,
#  'Carla_Sullivan': 765,
#  'Carla_Tricoli': 766,
#  'Carlos_Alberto': 767,
#  'Carlos_Alberto_Parreira': 768,
#  'Carlos_Arroyo': 769,
#  'Carlos_Barra': 770,
#  'Carlos_Barragan': 771,
#  'Carlos_Beltran': 772,
#  'Carlos_Bianchi': 773,
#  'Carlos_De_Abreu': 774,
#  'Carlos_Fasciolo': 775,
#  'Carlos_Ghosn': 776,
#  'Carlos_Iturgaitz': 777,
#  'Carlos_Juarez': 778,
#  'Carlos_Lordkipanitse': 779,
#  'Carlos_Manuel_Pruneda': 780,
#  'Carlos_Menem': 781,
#  'Carlos_Mesa': 782,
#  'Carlos_Moya': 783,
#  'Carlos_Ortega': 784,
#  'Carlos_Paternina': 785,
#  'Carlos_Queiroz': 786,
#  'Carlos_Quintanilla_Schmidt': 787,
#  'Carlos_Ruckauf': 788,
#  'Carlos_Ruiz': 789,
#  'Carlos_Salinas': 790,
#  'Carlos_Savedra': 791,
#  'Carlos_Vives': 792,
#  'Carlo_Ancelotti': 793,
#  'Carlo_Azeglio_Ciampi': 794,
#  'Carlton_Baugh': 795,
#  'Carlton_Dotson': 796,
#  'Carly_Fiorina': 797,
#  'Carly_Gullickson': 798,
#  'Carl_Levin': 799,
#  'Carl_Pope': 800,
#  'Carl_Reiner': 801,
#  'Carmen_Electra': 802,
#  'Carolina_Barco': 803,
#  'Carolina_Kluft': 804,
#  'Carolina_Moraes': 805,
#  'Caroline_Dhavernas': 806,
#  'Caroline_Kennedy': 807,
#  'Caroline_Link': 808,
#  'Carolyn_Dawn_Johnson': 809,
#  'Carolyn_Kuhl': 810,
#  'Carol_Burnett': 811,
#  'Carol_Carmody': 812,
#  'Carol_Moseley_Braun': 813,
#  'Carol_Niedermayer': 814,
#  'Carol_Williams': 815,
#  'Carrie-Anne_Moss': 816,
#  'Carroll_Weimer': 817,
#  'Carson_Daly': 818,
#  'Carson_Palmer': 819,
#  'Casey_Crowder': 820,
#  'Casey_Mears': 821,
#  'Cassandra_Heise': 822,
#  'Cass_Ballenger': 823,
#  'Casy_Preslar': 824,
#  'Cate_Blanchett': 825,
#  'Catherine_Bell': 826,
#  'Catherine_Deneuve': 827,
#  'Catherine_Donkers': 828,
#  'Catherine_Ndereba': 829,
#  'Catherine_Woodard': 830,
#  'Catherine_Zeta-Jones': 831,
#  'Cathryn_Crawford': 832,
#  'Cathy_Chisholm': 833,
#  'Cathy_Cunningham': 834,
#  'Cathy_Freeman': 835,
#  'Catriona_Le_May_Doan': 836,
#  'Cecile_de_France': 837,
#  'Cecilia_Bolocco': 838,
#  'Cecilia_Chang': 839,
#  'Cecilia_Cheung': 840,
#  'Cedric_Benson': 841,
#  'Celia_Cruz': 842,
#  'Celine_Dion': 843,
#  'Celso_Amorim': 844,
#  'Celso_Lafer': 845,
#  'Cemil_Cicek': 846,
#  'Cesar_Gaviria': 847,
#  'Cesar_Maia': 848,
#  'Chadha_Gurinder': 849,
#  'Chakib_Khelil': 850,
#  'Chance_Mock': 851,
#  'Chanda_Rubin': 852,
#  'Chandrika_Kumaratunga': 853,
#  'Chang_Dae-whan': 854,
#  'Chang_Jae_On': 855,
#  'Chang_Saio-yue': 856,
#  'Chang_Sang': 857,
#  'Chang_Tso': 858,
#  'Chante_Jawan_Mallard': 859,
#  'Chan_Choi': 860,
#  'Chan_Gailey': 861,
#  'Chan_Ho_Park': 862,
#  'Charla_Moye': 863,
#  'Charlene_Barshefsky': 864,
#  'Charles_Bell': 865,
#  'Charles_Bronson': 866,
#  'Charles_Chandler_IV': 867,
#  'Charles_Cope': 868,
#  'Charles_Grassley': 869,
#  'Charles_Holzner': 870,
#  'Charles_Ingram': 871,
#  'Charles_Kartman': 872,
#  'Charles_Lebois': 873,
#  'Charles_Mathews': 874,
#  'Charles_Moose': 875,
#  'Charles_Pickering': 876,
#  'Charles_Pouty': 877,
#  'Charles_Richardson': 878,
#  'Charles_Rogers': 879,
#  'Charles_Schumer': 880,
#  'Charles_Tannok': 881,
#  'Charles_Taylor': 882,
#  'Charley_Armey': 883,
#  'Charlie_Coles': 884,
#  'Charlie_Deane': 885,
#  'Charlie_Garner': 886,
#  'Charlie_Hunnam': 887,
#  'Charlie_Sheen': 888,
#  'Charlie_Williams': 889,
#  'Charlie_Zaa': 890,
#  'Charlize_Theron': 891,
#  'Charlotte_Casiraghi': 892,
#  'Charlotte_Chambers': 893,
#  'Charlotte_Church': 894,
#  'Charlotte_Rampling': 895,
#  'Charlton_Heston': 896,
#  'Charmaine_Crooks': 897,
#  'Chawki_Armali': 898,
#  'Cha_Yung-gu': 899,
#  'Chea_Sophara': 900,
#  'Chelsea_Clinton': 901,
#  'Chen_Kaige': 902,
#  'Chen_Liang_Yu': 903,
#  'Chen_Shui-bian': 904,
#  'Chen_Tsai-chin': 905,
#  'Cherie_Blair': 906,
#  'Cherry_Jones': 907,
#  'Cheryl_Ford': 908,
#  'Cheryl_Hines': 909,
#  'Cheryl_James': 910,
#  'Cheryl_Little': 911,
#  'Cheryl_Tiegs': 912,
#  'Chhouk_Rin': 913,
#  'Chick_Hearn': 914,
#  'Chin-Feng_Chen': 915,
#  'Chin-Hui_Tsao': 916,
#  'Chip_Burrus': 917,
#  'Chip_Ganassi': 918,
#  'Chip_Knight': 919,
#  'Chistian_Stahl': 920,
#  'Chita_Rivera': 921,
#  'Chloe_Sevigny': 922,
#  'Choi_Sung-hong': 923,
#  'Choi_Yun-yong': 924,
#  'Chok_Tong_Goh': 925,
#  'Cho_Myung-kyun': 926,
#  'Christiane_Wulff': 927,
#  'Christian_Bale': 928,
#  'Christian_Fittipaldi': 929,
#  'Christian_Gimenez': 930,
#  'Christian_Lacroix': 931,
#  'Christian_Lirette': 932,
#  'Christian_Longo': 933,
#  'Christian_Malcolm': 934,
#  'Christian_Olsson': 935,
#  'Christian_Patino': 936,
#  'Christian_Von_Wernich': 937,
#  'Christian_Wulff': 938,
#  'Christina_Aguilera': 939,
#  'Christina_Sawaya': 940,
#  'Christine_Arron': 941,
#  'Christine_Baumgartner': 942,
#  'Christine_Ebersole': 943,
#  'Christine_Gregoire': 944,
#  'Christine_Rau': 945,
#  'Christine_Todd_Whitman': 946,
#  'Christopher_Amolsch': 947,
#  'Christopher_Conyers': 948,
#  'Christopher_Matero': 949,
#  'Christopher_Patten': 950,
#  'Christopher_Reeve': 951,
#  'Christopher_Russell': 952,
#  'Christopher_Speer': 953,
#  'Christopher_Walken': 954,
#  'Christopher_Whittle': 955,
#  'Christoph_Daum': 956,
#  'Christy_Ferer': 957,
#  'Christy_Turlington': 958,
#  'Chris_Andrews': 959,
#  'Chris_Bell': 960,
#  'Chris_Byrd': 961,
#  'Chris_Cirino': 962,
#  'Chris_Claiborne': 963,
#  'Chris_Columbus': 964,
#  'Chris_Cookson': 965,
#  'Chris_Cooper': 966,
#  'Chris_Cornell': 967,
#  'Chris_Crocker': 968,
#  'Chris_Dodd': 969,
#  'Chris_Forsyth': 970,
#  'Chris_Gratton': 971,
#  'Chris_Hernandez': 972,
#  'Chris_Klein': 973,
#  'Chris_Kolanas': 974,
#  'Chris_Matthews': 975,
#  'Chris_Moore': 976,
#  'Chris_Neil': 977,
#  'Chris_Noth': 978,
#  'Chris_Penn': 979,
#  'Chris_Pronger': 980,
#  'Chris_Reitsma': 981,
#  'Chris_Rock': 982,
#  'Chris_Simon': 983,
#  'Chris_Swecker': 984,
#  'Chris_Terry': 985,
#  'Chris_Thomas': 986,
#  'Chris_Tucker': 987,
#  'Chris_Whitney': 988,
#  'Chuanyun_Li': 989,
#  'Chuck_Amato': 990,
#  'Chuck_Bednarik': 991,
#  'Chuck_Eidson': 992,
#  'Chuck_Finley': 993,
#  'Chuck_Hagel': 994,
#  'Chuck_Woolery': 995,
#  'Chuck_Yeager': 996,
#  'Chung_Mong-hun': 997,
#  'Chung_Mong-joon': 998,
#  'Chyung_Dai-chul': 999,
#  ...}

# %%
x_train=[]
y_train=[]
for i in range(len(dd)):
    x_train.append(dd[i]['image'])
    y_train.append(re_label[dd[i]['label']])
x_train=np.asarray(x_train)
y_train=np.asarray(y_train).reshape(len(dd),1)

# %%
print(y_train.shape)
# Out:
# (12623, 1)

# %%
model.predict(x_train[2:3])

# %%
labels
# Out:
# {0: 'Aaron_Eckhart',
#  1: 'Aaron_Guiel',
#  2: 'Aaron_Patterson',
#  3: 'Aaron_Peirsol',
#  4: 'Aaron_Pena',
#  5: 'Aaron_Sorkin',
#  6: 'Aaron_Tippin',
#  7: 'Abbas_Kiarostami',
#  8: 'Abba_Eban',
#  9: 'Abdel_Aziz_Al-Hakim',
#  10: 'Abdel_Madi_Shabneh',
#  11: 'Abdel_Nasser_Assidi',
#  12: 'Abdoulaye_Wade',
#  13: 'Abdulaziz_Kamilov',
#  14: 'Abdullah',
#  15: 'Abdullah_Ahmad_Badawi',
#  16: 'Abdullah_al-Attiyah',
#  17: 'Abdullah_Gul',
#  18: 'Abdullah_Nasseef',
#  19: 'Abdullatif_Sener',
#  20: 'Abdul_Majeed_Shobokshi',
#  21: 'Abdul_Rahman',
#  22: 'Abel_Aguilar',
#  23: 'Abel_Pacheco',
#  24: 'Abid_Hamid_Mahmud_Al-Tikriti',
#  25: 'Abner_Martinez',
#  26: 'Abraham_Foxman',
#  27: 'Aby_Har-Even',
#  28: 'Adam_Ant',
#  29: 'Adam_Freier',
#  30: 'Adam_Herbert',
#  31: 'Adam_Kennedy',
#  32: 'Adam_Mair',
#  33: 'Adam_Rich',
#  34: 'Adam_Sandler',
#  35: 'Adam_Scott',
#  36: 'Adelina_Avila',
#  37: 'Adel_Al-Jubeir',
#  38: 'Adisai_Bodharamik',
#  39: 'Adolfo_Aguilar_Zinser',
#  40: 'Adolfo_Rodriguez_Saa',
#  41: 'Adoor_Gopalakarishnan',
#  42: 'Adriana_Lima',
#  43: 'Adriana_Perez_Navarro',
#  44: 'Adrianna_Zuzic',
#  45: 'Adrian_Annus',
#  46: 'Adrian_Fernandez',
#  47: 'Adrian_McPherson',
#  48: 'Adrian_Murrell',
#  49: 'Adrian_Nastase',
#  50: 'Adrien_Brody',
#  51: 'Afton_Smith',
#  52: 'Agbani_Darego',
#  53: 'Agnelo_Queiroz',
#  54: 'Agnes_Bruckner',
#  55: 'Ahmad_Jbarah',
#  56: 'Ahmad_Masood',
#  57: 'Ahmed_Ahmed',
#  58: 'Ahmed_Chalabi',
#  59: 'Ahmed_Ghazi',
#  60: 'Ahmed_Ibrahim_Bilal',
#  61: 'Ahmed_Lopez',
#  62: 'Ahmed_Qureia',
#  63: 'Ahmet_Demir',
#  64: 'Ahmet_Necdet_Sezer',
#  65: 'Aicha_El_Ouafi',
#  66: 'Aidan_Quinn',
#  67: 'Aileen_Riggin_Soule',
#  68: 'Ainsworth_Dyer',
#  69: 'Ain_Seppik',
#  70: 'Aishwarya_Rai',
#  71: 'Aitor_Gonzalez',
#  72: 'Aiysha_Smith',
#  73: 'Ai_Sugiyama',
#  74: 'Ajit_Agarkar',
#  75: 'AJ_Cook',
#  76: 'AJ_Lamas',
#  77: 'Akbar_Al_Baker',
#  78: 'Akbar_Hashemi_Rafsanjani',
#  79: 'Akhmed_Zakayev',
#  80: 'Akiko_Morigami',
#  81: 'Akmal_Taher',
#  82: 'Alain_Cervantes',
#  83: 'Alain_Ducasse',
#  84: 'Alanis_Morissette',
#  85: 'Alanna_Ubach',
#  86: 'Alan_Ball',
#  87: 'Alan_Dershowitz',
#  88: 'Alan_Dreher',
#  89: 'Alan_Greenspan',
#  90: 'Alan_Greer',
#  91: 'Alan_Jackson',
#  92: 'Alan_Mulally',
#  93: 'Alan_Stonecipher',
#  94: 'Alan_Tang_Kwong-wing',
#  95: 'Alan_Trammell',
#  96: 'Alan_Zemaitis',
#  97: 'Alastair_Campbell',
#  98: 'Alastair_Johnston',
#  99: 'Albaro_Recoba',
#  100: 'Alberta_Lee',
#  101: 'Alberto_Acosta',
#  102: 'Alberto_Fujimori',
#  103: 'Alberto_Gonzales',
#  104: 'Alberto_Ruiz_Gallardon',
#  105: 'Alberto_Sordi',
#  106: 'Albert_Brooks',
#  107: 'Albert_Costa',
#  108: 'Albert_Montanes',
#  109: 'Albert_Pujols',
#  110: 'Albrecht_Mentz',
#  111: 'Aldo_Paredes',
#  112: 'Alecos_Markides',
#  113: 'Alec_Baldwin',
#  114: 'Alejandro_Atchugarry',
#  115: 'Alejandro_Avila',
#  116: 'Alejandro_Fernandez',
#  117: 'Alejandro_Gonzalez_Inarritu',
#  118: 'Alejandro_Lembo',
#  119: 'Alejandro_Lerner',
#  120: 'Alejandro_Lopez',
#  121: 'Alejandro_Toledo',
#  122: 'Aleksander_Kwasniewski',
#  123: 'Aleksander_Voloshin',
#  124: 'Alek_Wek',
#  125: 'Alessandra_Cerna',
#  126: 'Alessandro_Nesta',
#  127: 'Alexander_Downer',
#  128: 'Alexander_Losyukov',
#  129: 'Alexander_Lukashenko',
#  130: 'Alexander_Payne',
#  131: 'Alexander_Rumyantsev',
#  132: 'Alexandra_Jackson',
#  133: 'Alexandra_Pelosi',
#  134: 'Alexandra_Rozovskaya',
#  135: 'Alexandra_Spann',
#  136: 'Alexandra_Stevenson',
#  137: 'Alexandra_Vodjanikova',
#  138: 'Alexandre_Daigle',
#  139: 'Alexandre_Despatie',
#  140: 'Alexandre_Herchcovitch',
#  141: 'Alexandre_Vinokourov',
#  142: 'Alexa_Loren',
#  143: 'Alexa_Vega',
#  144: 'Alexis_Bledel',
#  145: 'Alexis_Dennisoff',
#  146: 'Alex_Barros',
#  147: 'Alex_Cabrera',
#  148: 'Alex_Cejka',
#  149: 'Alex_Corretja',
#  150: 'Alex_Ferguson',
#  151: 'Alex_Gonzalez',
#  152: 'Alex_Holmes',
#  153: 'Alex_King',
#  154: 'Alex_Penelas',
#  155: 'Alex_Popov',
#  156: 'Alex_Sink',
#  157: 'Alex_Wallau',
#  158: 'Alex_Zanardi',
#  159: 'Alfonso_Cuaron',
#  160: 'Alfonso_Portillo',
#  161: 'Alfonso_Soriano',
#  162: 'Alfredo_di_Stefano',
#  163: 'Alfredo_Moreno',
#  164: 'Alfredo_Pena',
#  165: 'Alfred_Ford',
#  166: 'Alfred_Sant',
#  167: 'Alice_Fisher',
#  168: 'Alicia_Hollowell',
#  169: 'Alicia_Keys',
#  170: 'Alicia_Molik',
#  171: 'Alicia_Silverstone',
#  172: 'Alicia_Witt',
#  173: 'Alimzhan_Tokhtakhounov',
#  174: 'Alina_Kabaeva',
#  175: 'Aline_Chretien',
#  176: 'Alisha_Richman',
#  177: 'Alison_Krauss',
#  178: 'Alison_Lohman',
#  179: 'Alistair_MacDonald',
#  180: 'Ali_Abbas',
#  181: 'Ali_Abdullah_Saleh',
#  182: 'Ali_Adbul_Karim_Madani',
#  183: 'Ali_Ahmeti',
#  184: 'Ali_Bin_Hussein',
#  185: 'Ali_Fallahian',
#  186: 'Ali_Hammoud',
#  187: 'Ali_Khamenei',
#  188: 'Ali_Mohammed_Maher',
#  189: 'Ali_Naimi',
#  190: 'Allan_Houston',
#  191: 'Allan_Kemakeza',
#  192: 'Allan_Wagner',
#  193: 'Allen_Iverson',
#  194: 'Allen_Rock',
#  195: 'Allison_Janney',
#  196: 'Allison_Searing',
#  197: 'Allyson_Felix',
#  198: 'Ally_Sheedy',
#  199: 'Alma_Powell',
#  200: 'Almeida_Baptista',
#  201: 'Alonzo_Mourning',
#  202: 'Alvaro_Noboa',
#  203: 'Alvaro_Silva_Calderon',
#  204: 'Alvaro_Uribe',
#  205: 'Alyse_Beaupre',
#  206: 'Alyson_Hannigan',
#  207: 'Aly_Wagner',
#  208: 'Al_Cardenas',
#  209: 'Al_Davis',
#  210: 'Al_Gore',
#  211: 'Al_Leiter',
#  212: 'Al_Pacino',
#  213: 'Al_Sharpton',
#  214: 'Amanda_Beard',
#  215: 'Amanda_Bynes',
#  216: 'Amanda_Coetzer',
#  217: 'Amanda_Marsh',
#  218: 'Amanda_Plumer',
#  219: 'Amber_Frey',
#  220: 'Amber_Tamblyn',
#  221: 'Ambrose_Lee',
#  222: 'Amelia_Vega',
#  223: 'Amelie_Mauresmo',
#  224: 'Amer_al-Saadi',
#  225: 'Amporn_Falise',
#  226: 'Amram_Mitzna',
#  227: 'Amr_Moussa',
#  228: 'Amy_Brenneman',
#  229: 'Amy_Cotton',
#  230: 'Amy_Gale',
#  231: 'Amy_Pascal',
#  232: 'Amy_Redford',
#  233: 'Amy_Smart',
#  234: 'Amy_Yasbeck',
#  235: 'Anastasia_Kelesidou',
#  236: 'Anastasia_Myskina',
#  237: 'Anatoliy_Kinakh',
#  238: 'Ana_Claudia_Talancon',
#  239: 'Ana_Guevara',
#  240: 'Ana_Isabel_Sanchez',
#  241: 'Ana_Palacio',
#  242: 'Ana_Paula_Gerard',
#  243: 'Ana_Sebastiao',
#  244: 'Anderson_Varejao',
#  245: 'Anders_Ebbeson',
#  246: 'Anders_Fogh_Rasmussen',
#  247: 'Andreas_Vinciguerra',
#  248: 'Andrea_Bocelli',
#  249: 'Andrea_De_Cruz',
#  250: 'Andrea_Kiser',
#  251: 'Andrea_Yates',
#  252: 'Andrei_Konchalovsky',
#  253: 'Andrei_Mikhnevich',
#  254: 'Andrei_Nikolishin',
#  255: 'Andres_DAlessandro',
#  256: 'Andres_Manuel_Lopez_Obrador',
#  257: 'Andres_Pastrana',
#  258: 'Andrew_Bernard',
#  259: 'Andrew_Bunner',
#  260: 'Andrew_Caldecott',
#  261: 'Andrew_Cuomo',
#  262: 'Andrew_Fastow',
#  263: 'Andrew_Firestone',
#  264: 'Andrew_Gilligan',
#  265: 'Andrew_Jarecki',
#  266: 'Andrew_Luster',
#  267: 'Andrew_Niccol',
#  268: 'Andrew_Sabey',
#  269: 'Andrew_Shutley',
#  270: 'Andrew_Weissmann',
#  271: 'Andrew_Wetzler',
#  272: 'Andre_Agassi',
#  273: 'Andre_Bucher',
#  274: 'Andre_Lange',
#  275: 'Andre_Smith',
#  276: 'Andre_Techine',
#  277: 'Andrzej_Tyszkiewicz',
#  278: 'Andy_Benes',
#  279: 'Andy_Bryant',
#  280: 'Andy_Dick',
#  281: 'Andy_Garcia',
#  282: 'Andy_Graves',
#  283: 'Andy_Griffith',
#  284: 'Andy_Griggs',
#  285: 'Andy_Hebb',
#  286: 'Andy_Lau',
#  287: 'Andy_Madikians',
#  288: 'Andy_North',
#  289: 'Andy_Perez',
#  290: 'Andy_Roddick',
#  291: 'Andy_Rooney',
#  292: 'Andy_Warhol',
#  293: 'Andy_Wisecarver',
#  294: 'Anette_Hosoi',
#  295: 'AnFernce_Negron',
#  296: 'Angela_Alvarado_Rosa',
#  297: 'Angela_Bassett',
#  298: 'Angela_Lansbury',
#  299: 'Angela_Mascia-Frye',
#  300: 'Angela_Merkel',
#  301: 'Angelica_Romero',
#  302: 'Angelina_Jolie',
#  303: 'Angelo_Genova',
#  304: 'Angelo_Reyes',
#  305: 'Angel_Lockward',
#  306: 'Angel_Maza',
#  307: 'Angie_Arzola',
#  308: 'Angie_Martinez',
#  309: 'Anibal_Ibarra',
#  310: 'Anil_Ramsook',
#  311: 'Anita_DeFrantz',
#  312: 'Anja_Paerson',
#  313: 'Anjum_Hussain',
#  314: 'Anna_Chicherova',
#  315: 'Anna_Faris',
#  316: 'Anna_Jones',
#  317: 'Anna_Kournikova',
#  318: 'Anna_Nicole_Smith',
#  319: 'Anneli_Jaatteenmaki',
#  320: 'Annette_Bening',
#  321: 'Annette_Lu',
#  322: 'Anne_Cavers',
#  323: 'Anne_Donovan',
#  324: 'Anne_Heche',
#  325: 'Anne_Krueger',
#  326: 'Anne_McLellan',
#  327: 'Anne_ONeil',
#  328: 'Annie-Jeanne_Reynaud',
#  329: 'Annie_Chaplin',
#  330: 'Annie_Machon',
#  331: 'Annika_Sorenstam',
#  332: 'Ann_Godbehere',
#  333: 'Ann_Landers',
#  334: 'Ann_Morgan',
#  335: 'Ann_Veneman',
#  336: 'Antanas_Valionis',
#  337: 'Anthony_Carter',
#  338: 'Anthony_Corso',
#  339: 'Anthony_Ervin',
#  340: 'Anthony_Fauci',
#  341: 'Anthony_Garotinho',
#  342: 'Anthony_Hazen',
#  343: 'Anthony_Hopkins',
#  344: 'Anthony_LaPaglia',
#  345: 'Anthony_Lee_Johnson',
#  346: 'Anthony_Mazur',
#  347: 'Anthony_Pico',
#  348: 'Anthony_Pisciotti',
#  349: 'Anthony_Principi',
#  350: 'Anthony_Rackauckas',
#  351: 'Anthony_Scott_Miller',
#  352: 'Antje_Buschschulte',
#  353: 'Antonio_Banderas',
#  354: 'Antonio_Bernardo',
#  355: 'Antonio_Cassano',
#  356: 'Antonio_Catania',
#  357: 'Antonio_Elias_Saca',
#  358: 'Antonio_Palocci',
#  359: 'Antonio_Trillanes',
#  360: 'Antony_Leung',
#  361: 'Anton_Balasingham',
#  362: 'Antwun_Echols',
#  363: 'Anwar_Ibrahim',
#  364: 'Anzori_Kikalishvili',
#  365: 'Aparna_Pillai',
#  366: 'Aram_Adler',
#  367: 'Arantxa_Sanchez-Vicario',
#  368: 'Aretha_Franklin',
#  369: 'Arianna_Huffington',
#  370: 'Ariel_Sharon',
#  371: 'Arie_Haan',
#  372: 'Arif_Mardin',
#  373: 'Ari_Bousbib',
#  374: 'Ari_Fleischer',
#  375: 'Arlen_Specter',
#  376: 'Armando_Avila_Panchame',
#  377: 'Armando_Calderon_Sol',
#  378: 'Armando_Carrillo',
#  379: 'Armand_Sargen',
#  380: 'Arminio_Fraga',
#  381: 'Arnaud_Clement',
#  382: 'Arnaud_Lagardere',
#  383: 'Arnie_Boehm',
#  384: 'Arnoldo_Aleman',
#  385: 'Arnold_Palmer',
#  386: 'Arnold_Schwarzenegger',
#  387: 'Arnold_Scott',
#  388: 'Aron_Ralston',
#  389: 'Arsinee_Khanjian',
#  390: 'Arthur_Johnson',
#  391: 'Arthur_Martinez',
#  392: 'Artieas_Shanks',
#  393: 'Arturo_Gatti',
#  394: 'Art_Cooper',
#  395: 'Art_Hoffmann',
#  396: 'Art_Howe',
#  397: 'Art_Lopez',
#  398: 'Arye_Mekel',
#  399: 'Asa_Hutchinson',
#  400: 'Ascencion_Barajas',
#  401: 'Ashanti',
#  402: 'Ashlea_Talbot',
#  403: 'Ashley_Judd',
#  404: 'Ashley_Olsen',
#  405: 'Ashley_Postell',
#  406: 'Ashraf_Alasmar',
#  407: 'Ashraf_Ghani',
#  408: 'Ashton_Kutcher',
#  409: 'Asif_Ali_Zardari',
#  410: 'Asif_Hanif',
#  411: 'Askar_Akayev',
#  412: 'Asmaa_Assad',
#  413: 'Assad_Ahmadi',
#  414: 'Astou_Ndiaye-Diatta',
#  415: 'Astrid_Betancourt',
#  416: 'Astrid_Eyzaguirre',
#  417: 'Atal_Bihari_Vajpayee',
#  418: 'Ataollah_Mohajerani',
#  419: 'Atiabet_Ijan_Amabel',
#  420: 'Atom_Egoyan',
#  421: 'Atsushi_Sato',
#  422: 'Audrey_Lacroix',
#  423: 'Audrey_Sauret',
#  424: 'Augustin_Calleri',
#  425: 'Augusto_Pinochet',
#  426: 'Augusto_Roa_Bastos',
#  427: 'Aung_San_Suu_Kyi',
#  428: 'Austin_Kearns',
#  429: 'Avril_Lavigne',
#  430: 'Azmi_Bishara',
#  431: 'Azra_Akin',
#  432: 'Babe_Ruth',
#  433: 'Baburam_Bhattari',
#  434: 'Bak_Chang-Ryun',
#  435: 'Barbara_Bach',
#  436: 'Barbara_Becker',
#  437: 'Barbara_Bodine',
#  438: 'Barbara_Boxer',
#  439: 'Barbara_Brezigar',
#  440: 'Barbara_De_Brun',
#  441: 'Barbara_Esbin',
#  442: 'Barbara_Felt-Miller',
#  443: 'Barbara_Roberts',
#  444: 'Barbara_Walters',
#  445: 'Barbora_Strycova',
#  446: 'Barbra_Streisand',
#  447: 'Barrett_Jackman',
#  448: 'Barry_Alvarez',
#  449: 'Barry_Bonds',
#  450: 'Barry_Collier',
#  451: 'Barry_Diller',
#  452: 'Barry_Ford',
#  453: 'Barry_Hinson',
#  454: 'Barry_Nakell',
#  455: 'Barry_Switzer',
#  456: 'Barry_Williams',
#  457: 'Barry_Zito',
#  458: 'Bartosz_Kizierowski',
#  459: 'Bart_Freundlich',
#  460: 'Bart_Hendricks',
#  461: 'Barzan_al-Tikriti',
#  462: 'Basdeo_Panday',
#  463: 'Bashar_Assad',
#  464: 'Baz_Luhrmann',
#  465: 'BB_King',
#  466: 'Beatrice_Dalle',
#  467: 'Beatriz_Merino',
#  468: 'Beecher_Ray_Kirby',
#  469: 'Begum_Khaleda_Zia',
#  470: 'Bela_Karolyi',
#  471: 'Benazir_Bhutto',
#  472: 'Benedita_da_Silva',
#  473: 'Benicio_Del_Toro',
#  474: 'Benito_Santiago',
#  475: 'Benjamin_Bratt',
#  476: 'Benjamin_Franklin',
#  477: 'Benjamin_Martinez',
#  478: 'Benjamin_McKenzie',
#  479: 'Benjamin_Netanyahu',
#  480: 'Benjamin_Neulander',
#  481: 'Ben_Affleck',
#  482: 'Ben_Betts',
#  483: 'Ben_Braun',
#  484: 'Ben_Broussard',
#  485: 'Ben_Cahoon',
#  486: 'Ben_Chandler',
#  487: 'Ben_Cohen',
#  488: 'Ben_Curtis',
#  489: 'Ben_Davis',
#  490: 'Ben_Glisan',
#  491: 'Ben_Howland',
#  492: 'Ben_Kingsley',
#  493: 'Ben_Lee',
#  494: 'Ben_Stein',
#  495: 'Ben_Wallace',
#  496: 'Bernadette_Peters',
#  497: 'Bernardo_Segura',
#  498: 'Bernard_Ebbers',
#  499: 'Bernard_Giraudeau',
#  500: 'Bernard_Kerik',
#  501: 'Bernard_Landry',
#  502: 'Bernard_Law',
#  503: 'Bernard_Lord',
#  504: 'Bernard_Siegel',
#  505: 'Bernice_Wong',
#  506: 'Bertie_Ahern',
#  507: 'Bertrand_Bonello',
#  508: 'Bertrand_Delanoe',
#  509: 'Beth_Blough',
#  510: 'Beth_Jones',
#  511: 'Betsy_Coffin',
#  512: 'Betsy_Smith',
#  513: 'Bettina_Rheims',
#  514: 'Betty_Garrison',
#  515: 'Betty_Williams',
#  516: 'Beyonce_Knowles',
#  517: 'Bianca_Jagger',
#  518: 'Bijan_Darvish',
#  519: 'Bijan_Namdar_Zangeneh',
#  520: 'Bilal_Erdogan',
#  521: 'Biljana_Plavsic',
#  522: 'Billy_Andrade',
#  523: 'Billy_Beane',
#  524: 'Billy_Bob_Thornton',
#  525: 'Billy_Boyd',
#  526: 'Billy_Crawford',
#  527: 'Billy_Crystal',
#  528: 'Billy_Donovan',
#  529: 'Billy_Edelin',
#  530: 'Billy_Gilman',
#  531: 'Billy_Graham',
#  532: 'Billy_Joel',
#  533: 'Billy_Rork',
#  534: 'Billy_Sollie',
#  535: 'Billy_Tibbets',
#  536: 'Bill_Belichick',
#  537: 'Bill_Bradley',
#  538: 'Bill_Butler',
#  539: 'Bill_Byrne',
#  540: 'Bill_Callahan',
#  541: 'Bill_Carmody',
#  542: 'Bill_Cartwright',
#  543: 'Bill_Clancy',
#  544: 'Bill_Clinton',
#  545: 'Bill_Curry',
#  546: 'Bill_Doba',
#  547: 'Bill_Duffey',
#  548: 'Bill_Elliott',
#  549: 'Bill_Fennelly',
#  550: 'Bill_Frist',
#  551: 'Bill_Gates',
#  552: 'Bill_Graham',
#  553: 'Bill_Guerin',
#  554: 'Bill_Herrion',
#  555: 'Bill_Hughes',
#  556: 'Bill_King',
#  557: 'Bill_Kollar',
#  558: 'Bill_Kong',
#  559: 'Bill_Lerach',
#  560: 'Bill_Maher',
#  561: 'Bill_Mauldin',
#  562: 'Bill_McBride',
#  563: 'Bill_Nelson',
#  564: 'Bill_OReilly',
#  565: 'Bill_Parcells',
#  566: 'Bill_Parsons',
#  567: 'Bill_Paxton',
#  568: 'Bill_Pryor',
#  569: 'Bill_Rainer',
#  570: 'Bill_Readdy',
#  571: 'Bill_Richardson',
#  572: 'Bill_Self',
#  573: 'Bill_Simon',
#  574: 'Bill_Sizemore',
#  575: 'Bill_Stapleton',
#  576: 'Bill_Stein',
#  577: 'Bill_Walton',
#  578: 'Bing_Crosby',
#  579: 'Binyamin_Ben-Eliezer',
#  580: 'Bison_Dele',
#  581: 'Bixente_LIzarazu',
#  582: 'BJ_Habibie',
#  583: 'Blas_Ople',
#  584: 'Blythe_Danner',
#  585: 'Blythe_Hartley',
#  586: 'Bobby_Bowden',
#  587: 'Bobby_Goldwater',
#  588: 'Bobby_Jackson',
#  589: 'Bobby_Kielty',
#  590: 'Bobby_Robson',
#  591: 'Bobo_Balde',
#  592: 'Bob_Alper',
#  593: 'Bob_Beauprez',
#  594: 'Bob_Bowlsby',
#  595: 'Bob_Cantrell',
#  596: 'Bob_Colvin',
#  597: 'Bob_Crippen',
#  598: 'Bob_Curtis',
#  599: 'Bob_Dole',
#  600: 'Bob_Eskridge',
#  601: 'Bob_Ferguson',
#  602: 'Bob_Geldof',
#  603: 'Bob_Goldman',
#  604: 'Bob_Graham',
#  605: 'Bob_Guccione',
#  606: 'Bob_Hartley',
#  607: 'Bob_Hayes',
#  608: 'Bob_Herz',
#  609: 'Bob_Holden',
#  610: 'Bob_Hope',
#  611: 'Bob_Huggins',
#  612: 'Bob_Iger',
#  613: 'Bob_Krueger',
#  614: 'Bob_Melvin',
#  615: 'Bob_Menendez',
#  616: 'Bob_Newhart',
#  617: 'Bob_Petrino',
#  618: 'Bob_Riley',
#  619: 'Bob_Stoops',
#  620: 'Bob_Sulkin',
#  621: 'Bob_Taft',
#  622: 'Bob_Wright',
#  623: 'Bode_Miller',
#  624: 'Bonnie_Fuller',
#  625: 'Bonnie_Hunt',
#  626: 'Bono',
#  627: 'Boris_Becker',
#  628: 'Boris_Berezovsky',
#  629: 'Boris_Henry',
#  630: 'Boris_Jordan',
#  631: 'Boris_Trajkovski',
#  632: 'Boris_Yeltsin',
#  633: 'Boutros_Boutros_Ghali',
#  634: 'Bo_Pelini',
#  635: 'Bo_Ryan',
#  636: 'Brady_Rodgers',
#  637: 'Brad_Alexander_Smith',
#  638: 'Brad_Banks',
#  639: 'Brad_Brownell',
#  640: 'Brad_Garrett',
#  641: 'Brad_Gushue',
#  642: 'Brad_Johnson',
#  643: 'Brad_Miller',
#  644: 'Brad_Pitt',
#  645: 'Brad_Russ',
#  646: 'Brad_Smith',
#  647: 'Brad_Wilk',
#  648: 'Brajesh_Mishra',
#  649: 'Brandon_Boyd',
#  650: 'Brandon_Fails',
#  651: 'Brandon_Hammond',
#  652: 'Brandon_Inge',
#  653: 'Brandon_Jones',
#  654: 'Brandon_Knight',
#  655: 'Brandon_Larson',
#  656: 'Brandon_Lloyd',
#  657: 'Brandon_Robinson',
#  658: 'Brandon_Spann',
#  659: 'Brandon_Webb',
#  660: 'Branko_Crvenkovski',
#  661: 'Brawley_King',
#  662: 'Brendan_Fraser',
#  663: 'Brendan_Gaughan',
#  664: 'Brendan_Hansen',
#  665: 'Brendan_Stai',
#  666: 'Brenda_Magana',
#  667: 'Brenda_van_Dam',
#  668: 'Brenda_Wilson',
#  669: 'Brennon_Leighton',
#  670: 'Brent_Coles',
#  671: 'Brett_Boone',
#  672: 'Brett_Hawke',
#  673: 'Brett_Hull',
#  674: 'Brett_Perry',
#  675: 'Brian_Billick',
#  676: 'Brian_Campbell',
#  677: 'Brian_Cashman',
#  678: 'Brian_Clemens',
#  679: 'Brian_Cook',
#  680: 'Brian_Cowen',
#  681: 'Brian_De_Palma',
#  682: 'Brian_Florence',
#  683: 'Brian_Grazier',
#  684: 'Brian_Gregory',
#  685: 'Brian_Griese',
#  686: 'Brian_Heidik',
#  687: 'Brian_Henson',
#  688: 'Brian_Jordan',
#  689: 'Brian_Kerr',
#  690: 'Brian_Lara',
#  691: 'Brian_McIntyre',
#  692: 'Brian_Meadors',
#  693: 'Brian_Mulroney',
#  694: 'Brian_Olson',
#  695: 'Brian_Pavlich',
#  696: 'Brian_Scalabrine',
#  697: 'Brian_Schneider',
#  698: 'Brian_StPierre',
#  699: 'Brian_Van_Dusen',
#  700: 'Brian_Weaver',
#  701: 'Brian_Wells',
#  702: 'Brian_Williams',
#  703: 'Bridgette_Wilson-Sampras',
#  704: 'Bridget_Fonda',
#  705: 'Brigitte_Boisselier',
#  706: 'Britney_Spears',
#  707: 'Brittany_Snow',
#  708: 'Brock_Berlin',
#  709: 'Bronson_Arroyo',
#  710: 'Brooke_Adams',
#  711: 'Brooke_Gordon',
#  712: 'Brooke_Shields',
#  713: 'Brook_Robinson',
#  714: 'Bruce_Arena',
#  715: 'Bruce_Gebhardt',
#  716: 'Bruce_Lunsford',
#  717: 'Bruce_Paltrow',
#  718: 'Bruce_Springsteen',
#  719: 'Bruce_Van_De_Velde',
#  720: 'Bruce_Weber',
#  721: 'Bruce_Willis',
#  722: 'Bruna_Colosio',
#  723: 'Bruno_Junquiera',
#  724: 'Bryant_Young',
#  725: 'Bryan_Adams',
#  726: 'Bryan_Chui',
#  727: 'Bryan_Cooley',
#  728: 'Bryan_Murray',
#  729: 'Bryan_Thomas',
#  730: 'Bryce_Carmine',
#  731: 'Buck_Rodgers',
#  732: 'Buddy_Ryan',
#  733: 'Budd_Schulberg',
#  734: 'Bud_Selig',
#  735: 'Buford_Blount',
#  736: 'Bulent_Ecevit',
#  737: 'Bustam_A_Zedan_Aljanabi',
#  738: 'Butch_Davis',
#  739: 'Buzz_Hargrove',
#  740: 'Byron_Scott',
#  741: 'Cabas',
#  742: 'Caio_Blat',
#  743: 'Calbert_Cheaney',
#  744: 'Calista_Flockhart',
#  745: 'Calvin_Harrison',
#  746: 'Calvin_Joseph_Coleman',
#  747: 'Cameron_Diaz',
#  748: 'Camilla_Parker_Bowles',
#  749: 'Camille_Colvin',
#  750: 'Camille_Lewis',
#  751: 'Camryn_Manheim',
#  752: 'Candace_Sutton',
#  753: 'Candice_Beatty',
#  754: 'Candice_Bergen',
#  755: 'Candie_Kung',
#  756: 'Carey_Lowell',
#  757: 'Carina_Lau_Ka-ling',
#  758: 'Carin_Koch',
#  759: 'Cari_Davis',
#  760: 'Carla_Del_Ponte',
#  761: 'Carla_Gay_Balingit',
#  762: 'Carla_Gugino',
#  763: 'Carla_Moreno',
#  764: 'Carla_Myers',
#  765: 'Carla_Sullivan',
#  766: 'Carla_Tricoli',
#  767: 'Carlos_Alberto',
#  768: 'Carlos_Alberto_Parreira',
#  769: 'Carlos_Arroyo',
#  770: 'Carlos_Barra',
#  771: 'Carlos_Barragan',
#  772: 'Carlos_Beltran',
#  773: 'Carlos_Bianchi',
#  774: 'Carlos_De_Abreu',
#  775: 'Carlos_Fasciolo',
#  776: 'Carlos_Ghosn',
#  777: 'Carlos_Iturgaitz',
#  778: 'Carlos_Juarez',
#  779: 'Carlos_Lordkipanitse',
#  780: 'Carlos_Manuel_Pruneda',
#  781: 'Carlos_Menem',
#  782: 'Carlos_Mesa',
#  783: 'Carlos_Moya',
#  784: 'Carlos_Ortega',
#  785: 'Carlos_Paternina',
#  786: 'Carlos_Queiroz',
#  787: 'Carlos_Quintanilla_Schmidt',
#  788: 'Carlos_Ruckauf',
#  789: 'Carlos_Ruiz',
#  790: 'Carlos_Salinas',
#  791: 'Carlos_Savedra',
#  792: 'Carlos_Vives',
#  793: 'Carlo_Ancelotti',
#  794: 'Carlo_Azeglio_Ciampi',
#  795: 'Carlton_Baugh',
#  796: 'Carlton_Dotson',
#  797: 'Carly_Fiorina',
#  798: 'Carly_Gullickson',
#  799: 'Carl_Levin',
#  800: 'Carl_Pope',
#  801: 'Carl_Reiner',
#  802: 'Carmen_Electra',
#  803: 'Carolina_Barco',
#  804: 'Carolina_Kluft',
#  805: 'Carolina_Moraes',
#  806: 'Caroline_Dhavernas',
#  807: 'Caroline_Kennedy',
#  808: 'Caroline_Link',
#  809: 'Carolyn_Dawn_Johnson',
#  810: 'Carolyn_Kuhl',
#  811: 'Carol_Burnett',
#  812: 'Carol_Carmody',
#  813: 'Carol_Moseley_Braun',
#  814: 'Carol_Niedermayer',
#  815: 'Carol_Williams',
#  816: 'Carrie-Anne_Moss',
#  817: 'Carroll_Weimer',
#  818: 'Carson_Daly',
#  819: 'Carson_Palmer',
#  820: 'Casey_Crowder',
#  821: 'Casey_Mears',
#  822: 'Cassandra_Heise',
#  823: 'Cass_Ballenger',
#  824: 'Casy_Preslar',
#  825: 'Cate_Blanchett',
#  826: 'Catherine_Bell',
#  827: 'Catherine_Deneuve',
#  828: 'Catherine_Donkers',
#  829: 'Catherine_Ndereba',
#  830: 'Catherine_Woodard',
#  831: 'Catherine_Zeta-Jones',
#  832: 'Cathryn_Crawford',
#  833: 'Cathy_Chisholm',
#  834: 'Cathy_Cunningham',
#  835: 'Cathy_Freeman',
#  836: 'Catriona_Le_May_Doan',
#  837: 'Cecile_de_France',
#  838: 'Cecilia_Bolocco',
#  839: 'Cecilia_Chang',
#  840: 'Cecilia_Cheung',
#  841: 'Cedric_Benson',
#  842: 'Celia_Cruz',
#  843: 'Celine_Dion',
#  844: 'Celso_Amorim',
#  845: 'Celso_Lafer',
#  846: 'Cemil_Cicek',
#  847: 'Cesar_Gaviria',
#  848: 'Cesar_Maia',
#  849: 'Chadha_Gurinder',
#  850: 'Chakib_Khelil',
#  851: 'Chance_Mock',
#  852: 'Chanda_Rubin',
#  853: 'Chandrika_Kumaratunga',
#  854: 'Chang_Dae-whan',
#  855: 'Chang_Jae_On',
#  856: 'Chang_Saio-yue',
#  857: 'Chang_Sang',
#  858: 'Chang_Tso',
#  859: 'Chante_Jawan_Mallard',
#  860: 'Chan_Choi',
#  861: 'Chan_Gailey',
#  862: 'Chan_Ho_Park',
#  863: 'Charla_Moye',
#  864: 'Charlene_Barshefsky',
#  865: 'Charles_Bell',
#  866: 'Charles_Bronson',
#  867: 'Charles_Chandler_IV',
#  868: 'Charles_Cope',
#  869: 'Charles_Grassley',
#  870: 'Charles_Holzner',
#  871: 'Charles_Ingram',
#  872: 'Charles_Kartman',
#  873: 'Charles_Lebois',
#  874: 'Charles_Mathews',
#  875: 'Charles_Moose',
#  876: 'Charles_Pickering',
#  877: 'Charles_Pouty',
#  878: 'Charles_Richardson',
#  879: 'Charles_Rogers',
#  880: 'Charles_Schumer',
#  881: 'Charles_Tannok',
#  882: 'Charles_Taylor',
#  883: 'Charley_Armey',
#  884: 'Charlie_Coles',
#  885: 'Charlie_Deane',
#  886: 'Charlie_Garner',
#  887: 'Charlie_Hunnam',
#  888: 'Charlie_Sheen',
#  889: 'Charlie_Williams',
#  890: 'Charlie_Zaa',
#  891: 'Charlize_Theron',
#  892: 'Charlotte_Casiraghi',
#  893: 'Charlotte_Chambers',
#  894: 'Charlotte_Church',
#  895: 'Charlotte_Rampling',
#  896: 'Charlton_Heston',
#  897: 'Charmaine_Crooks',
#  898: 'Chawki_Armali',
#  899: 'Cha_Yung-gu',
#  900: 'Chea_Sophara',
#  901: 'Chelsea_Clinton',
#  902: 'Chen_Kaige',
#  903: 'Chen_Liang_Yu',
#  904: 'Chen_Shui-bian',
#  905: 'Chen_Tsai-chin',
#  906: 'Cherie_Blair',
#  907: 'Cherry_Jones',
#  908: 'Cheryl_Ford',
#  909: 'Cheryl_Hines',
#  910: 'Cheryl_James',
#  911: 'Cheryl_Little',
#  912: 'Cheryl_Tiegs',
#  913: 'Chhouk_Rin',
#  914: 'Chick_Hearn',
#  915: 'Chin-Feng_Chen',
#  916: 'Chin-Hui_Tsao',
#  917: 'Chip_Burrus',
#  918: 'Chip_Ganassi',
#  919: 'Chip_Knight',
#  920: 'Chistian_Stahl',
#  921: 'Chita_Rivera',
#  922: 'Chloe_Sevigny',
#  923: 'Choi_Sung-hong',
#  924: 'Choi_Yun-yong',
#  925: 'Chok_Tong_Goh',
#  926: 'Cho_Myung-kyun',
#  927: 'Christiane_Wulff',
#  928: 'Christian_Bale',
#  929: 'Christian_Fittipaldi',
#  930: 'Christian_Gimenez',
#  931: 'Christian_Lacroix',
#  932: 'Christian_Lirette',
#  933: 'Christian_Longo',
#  934: 'Christian_Malcolm',
#  935: 'Christian_Olsson',
#  936: 'Christian_Patino',
#  937: 'Christian_Von_Wernich',
#  938: 'Christian_Wulff',
#  939: 'Christina_Aguilera',
#  940: 'Christina_Sawaya',
#  941: 'Christine_Arron',
#  942: 'Christine_Baumgartner',
#  943: 'Christine_Ebersole',
#  944: 'Christine_Gregoire',
#  945: 'Christine_Rau',
#  946: 'Christine_Todd_Whitman',
#  947: 'Christopher_Amolsch',
#  948: 'Christopher_Conyers',
#  949: 'Christopher_Matero',
#  950: 'Christopher_Patten',
#  951: 'Christopher_Reeve',
#  952: 'Christopher_Russell',
#  953: 'Christopher_Speer',
#  954: 'Christopher_Walken',
#  955: 'Christopher_Whittle',
#  956: 'Christoph_Daum',
#  957: 'Christy_Ferer',
#  958: 'Christy_Turlington',
#  959: 'Chris_Andrews',
#  960: 'Chris_Bell',
#  961: 'Chris_Byrd',
#  962: 'Chris_Cirino',
#  963: 'Chris_Claiborne',
#  964: 'Chris_Columbus',
#  965: 'Chris_Cookson',
#  966: 'Chris_Cooper',
#  967: 'Chris_Cornell',
#  968: 'Chris_Crocker',
#  969: 'Chris_Dodd',
#  970: 'Chris_Forsyth',
#  971: 'Chris_Gratton',
#  972: 'Chris_Hernandez',
#  973: 'Chris_Klein',
#  974: 'Chris_Kolanas',
#  975: 'Chris_Matthews',
#  976: 'Chris_Moore',
#  977: 'Chris_Neil',
#  978: 'Chris_Noth',
#  979: 'Chris_Penn',
#  980: 'Chris_Pronger',
#  981: 'Chris_Reitsma',
#  982: 'Chris_Rock',
#  983: 'Chris_Simon',
#  984: 'Chris_Swecker',
#  985: 'Chris_Terry',
#  986: 'Chris_Thomas',
#  987: 'Chris_Tucker',
#  988: 'Chris_Whitney',
#  989: 'Chuanyun_Li',
#  990: 'Chuck_Amato',
#  991: 'Chuck_Bednarik',
#  992: 'Chuck_Eidson',
#  993: 'Chuck_Finley',
#  994: 'Chuck_Hagel',
#  995: 'Chuck_Woolery',
#  996: 'Chuck_Yeager',
#  997: 'Chung_Mong-hun',
#  998: 'Chung_Mong-joon',
#  999: 'Chyung_Dai-chul',
#  ...}

# %%
y_train[:32]
# Out:
# array([[ 0],
#        [ 1],
#        [ 2],
#        [ 3],
#        [ 3],
#        [ 3],
#        [ 4],
#        [ 5],
#        [ 5],
#        [ 6],
#        [ 7],
#        [ 8],
#        [ 9],
#        [10],
#        [11],
#        [11],
#        [12],
#        [12],
#        [12],
#        [13],
#        [14],
#        [14],
#        [14],
#        [15],
#        [16],
#        [16],
#        [16],
#        [17],
#        [17],
#        [17],
#        [17],
#        [17]])

# %%
pickle.dump(x_train,open('x_train.pkl','wb'))
pickle.dump(y_train,open('y_train.pkl','wb'))
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-43-863051996ad9> in <module>()
# ----> 1 pickle.dump(x_train,open('x_train.pkl','wb'))
#       2 pickle.dump(y_train,open('y_train.pkl','wb'))
#
# MemoryError:
